# %%
import pandas as pd

# %%
machine = pd.read_csv('newdemo.csv')
# Out:
#     Project ID  Start Date        Part ID  Quantity  \
# 0       T-1910  21-07-2021  Cavity Insert      36.0
# 1          NaN         NaN            NaN       NaN
# 2          NaN         NaN            NaN       NaN
# 3          NaN         NaN            NaN       NaN
# 4          NaN         NaN            NaN       NaN
# ..         ...         ...            ...       ...
# 98         NaN         NaN            NaN       NaN
# 99         NaN         NaN            NaN       NaN
# 100        NaN         NaN            NaN       NaN
# 101        NaN         NaN            NaN       NaN
# 102        NaN         NaN            NaN       NaN
#
#                         Process  Time
# 0                   SG Block up  0.36
# 1    CNC Turning Bottom Setting  0.36
# 2       CNC Turning Top Setting  0.54
# 3                  CNC Milling   0.36
# 4        Insert Identification   0.36
# ..                          ...   ...
# 98                          NaN   NaN
# ...

# %%
newmach = (machine.fillna(method='ffill'))
# Out:
#     Project ID  Start Date          Part ID  Quantity  \
# 0       T-1910  21-07-2021    Cavity Insert      36.0
# 1       T-1910  21-07-2021    Cavity Insert      36.0
# 2       T-1910  21-07-2021    Cavity Insert      36.0
# 3       T-1910  21-07-2021    Cavity Insert      36.0
# 4       T-1910  21-07-2021    Cavity Insert      36.0
# ..         ...         ...              ...       ...
# 98      T-1912  25-07-2021  Stripper Insert      36.0
# 99      T-1912  25-07-2021  Stripper Insert      36.0
# 100     T-1912  25-07-2021  Stripper Insert      36.0
# 101     T-1912  25-07-2021  Stripper Insert      36.0
# 102     T-1912  25-07-2021  Stripper Insert      36.0
#
#                         Process  Time
# 0                   SG Block up  0.36
# 1    CNC Turning Bottom Setting  0.36
# 2       CNC Turning Top Setting  0.54
# 3                  CNC Milling   0.36
# 4        Insert Identification   0.36
# ..                          ...   ...
# 98                  Inspection   0.14
# ...

# %%
newmach.to_csv('newdemoedit.csv')
